# %% [markdown]
# # FINAL REPORT BATTLE OF NEIGHBORHOODS

# %% [markdown]
# ## Introduction
#  This project encapsulates leveraging the Foursquare location data to explore the communities and respective neighborhoods of the city of Minneapolis in the state of Minnesota so as to make recommendations for the most suitable location for Asian Business headquarters and manufacturing plant.

# %% [markdown]
# # 1.0 PROBLEM STATEMENT
# ## 1.1 Background
# "Xantan LLC" South-Korean Based company is looking to expand its business operations in the United states and wanting to set its offices and manufacturing plant in the states of Minnesota and the city of Minneapolis but they are running out of time to deploy scout men to USA for a possible venue of operation meeting key location parameters.
# As a consultant i was contacted to solve this complex equation and make a recommendation to the CEO of the company
#
# ## 1.2 Key Location Characteristics
# > -  Office size within 2000 - 7000 sq ft
# > -  At least one Asian restaurant with 2 mile radius, coffee shop and Grocery
# > -  Asian community be most predominant or most important in the area
# > -  within one mile from bus station or bus-stop
# > -  Manufacturing plant be Within 5 miles of major Office and a major retail center
# > -  Manufacturing plant with 5 miles of a industrial employment district
# > -  Low crime rate

# %% [markdown]
# # 1.3. DATA
# ## 1.3.1 Data Sources
# > -  Data will principally come from 'OPENDATAMINNEAPOLIS'
#     (The City of Minneapolis public spatial geographic information systems (GIS) and non-spatial data that is regularly requested by private citizens and businesses. These data sets are shared free of charge and with minimal licensing).
#
# ### 1.3.2 Links to Key data to be used in the study
# > -  major retail centers: https://opendata.arcgis.com/datasets/2c35bcea1a7c4a3ba48fa42b039e5aa6_0.geojson
# > -  industrial employment districts: https://opendata.arcgis.com/datasets/4c768a5aa3154f85bd80dc9c5dd0ebf7_0.geojson
# > -  neighborhood commercial nodes: https://opendata.arcgis.com/datasets/47a7b23ee906431eb646f863ad2cb2e5_0.geojson
# > -  neighborhood crime stat: https://opendata.arcgis.com/datasets/e251c3fe668243719001237d7ac74420_0.geojson
# > -  Transit stations: https://opendata.arcgis.com/datasets/55a4601b78404583be59165006da9ad8_0.geojson
# > -  neighborhood and communities listing: http://www.ci.minneapolis.mn.us/council/maps/index.htm
# > -  office lease site: https://www.cityfeet.com/cont/minneapolis-mn/office-space-for-lease?sizeMin=1000&l=3-49492
# > -  communities: https://opendata.arcgis.com/datasets/e0a3b6a4c23b4a03b988388553cb9638_0.geojson
# > -  neighborhoods: https://opendata.arcgis.com/datasets/7f88316841ce471faa33c89035fb69e8_0.geojson
# > -  Fire stations: https://opendata.arcgis.com/datasets/e697e12884fd4421abaf4a71b513f509_0.geojson
#
# some of the files can be downloaded in CSV format while i had to scrape websites for rent information, neighborhoods and the communities
#
# ### 1.3.3 How will data be used to solve the problem
# > -  convert addresses into their equivalent latitude and longitude values unsing Geopy-distance and Nominatim, alternatively i will using OpenCage Geocoder API(free registration on the website)
# > -  Four square API will be used to generate to explore communities and neighborhoods in Minneapolis. I will use the explore function to get the most common venue categories in each neighborhood.
# > -  leverage the four square API explore function together with k-means clustering algorithm to group the neighborhoods into clusters.
# > -  I will use the Folium library to visualize the neighborhoods in Minneapolis and their emerging clusters with respect to the location specification of Xantan LLc and make a superposition to determine the best location.
# > -  I equally made use of charts( horizontal bar charts and pie chart to represent population distribution by RACE in the various (11) communities of Minneapolies. This was instrumental in population density evaluation
#
# ### 1.3.4 Possible Target audiences
# > -  Multinationals(public, private, NGO) seeking to explore and make strategic business decisons
# > -  individuals( seeking to relocate or setup business)
# > -  students getting their feet wet with data science methodology and APIs

# %% [markdown]
# ### 1.3.5 LIBRARIES AND DEPENDENCIES used in the study

# %% [markdown]
# > - numpy as np # library to handle data in a vectorized manner
# > - pandas as pd # library for data analsysis
# > - json # library to handle JSON files
# > - requests # library to handle requests
# > - pandas.io.json
# > - json_normalize # tranform JSON file into a pandas dataframe
# >-  folium=0.5.0
# > - Foursquare API lab
# >-  Opencage
# > - folium # map rendering library
# > - plugins
# > - geopy
# > - geopy.geocoders
# > - Nominatim # convert an address into latitude and longitude values
# > - Matplotlib and associated plotting modules
# > - matplotlib.cm as cm
# > - matplotlib.colors as colors
# > - matplotlib.pyplot as plt # plotting library
# > - seaborn as sns
# > - %matplotlib inline
# > - sklearn
# > - KMeans
# > - xlrd

# %% [markdown]
# # 1.4.0 RESULTS

# %% [markdown]
# #### 1.4.1 Communities, Neighborhoods in Minneapolis and their respective geo cordinates from OPENCAGE API, and Nominatin

# %% [markdown]
# ![title](min_csv_data/neigborhood.JPG)

# %% [markdown]
# #### Create a map of Minneapolis with neighborhoods superimposed on top

# %% [markdown]
# ![title](min_csv_data/display_nghd.JPG)

# %% [markdown]
# ## 1.4.2 Exploring and segmenting neighborhoods in Minneapolis using Four Square API with half a mile radius and 100 venues

# %% [markdown]
# #### Now write the code to run the above function on each neighborhood in Minneapolis

# %% [markdown]
# ![title](min_csv_data/foursqaure_venues.JPG)

# %% [markdown]
# ##### There are 234 uniques categories.with a size of the new data frame (971, 235) after one hot encoding
# ##### NEW size after grouping data (81, 235)

# %% [markdown]
# #### Let's print each neighborhood along with the top 5 most common venues

# %% [markdown]
# ![title](min_csv_data/grouping_neighbor.JPG),![title](min_csv_data/grouping_neighbor2.JPG)

# %% [markdown]
# #### Top 10 venues per Neighborhood

# %% [markdown]
# ![title](min_csv_data/top10_venues.JPG)

# %% [markdown]
# ## 1.4.3 Cluster Neighborhoods

# %% [markdown]
# The best cluster was archieved at values of K= 6, with the following array array([1, 3, 2, 2, 2, 2, 1, 1, 2, 2], dtype=int32)
#
# ![title](min_csv_data/clustering_groups.JPG)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %% [markdown]
# ![title](min_csv_data/data_framecluster.JPG)

# %% [markdown]
# visualize the resulting clusters

# %% [markdown]
# ![title](min_csv_data/clusters.JPG)

# %% [markdown]
# ## 1.4.4 CLUSTER EXAMINATION

# %% [markdown]
# examine each cluster and determine the discriminating venue categories that distinguish each cluster, focus is on cluster 3, since it houses a key factor of importance (Asian restaurants are focused in this cluster and major transit stations and

# %% [markdown]
# ![title](min_csv_data/cluster 30.JPG)
# ![title](min_csv_data/cluster_3.JPG)
# ![title](min_csv_data/cluster_3b.JPG)
# ![title](min_csv_data/cluster_3c.JPG)
# ![title](min_csv_data/cluster_3d.JPG)
# ![title](min_csv_data/cluster_3e.JPG)

# %% [markdown]
# #### Cluster see code for clusters 1,4,5,6

# %% [markdown]
# #### Cluster 2

# %%
minneapolis_merged.loc[minneapolis_merged['Cluster Labels'] == 1, minneapolis_merged.columns[[1] + list(range(5, minneapolis_merged.shape[1]))]]
# Out:
#         Neighborhoods 1st Most Common Venue 2nd Most Common Venue  \
# 0           Bryn Mawr           Coffee Shop          Intersection
# 1               CARAG           Coffee Shop                  Park
# 18        Elliot Park           Sports Club           Coffee Shop
# 24               Howe   Indie Movie Theater            Restaurant
# 58   Midtown Phillips           Coffee Shop              Gym Pool
# 59      Phillips West           Coffee Shop   American Restaurant
# 67           Standish                School           Coffee Shop
#
#    3rd Most Common Venue 4th Most Common Venue   5th Most Common Venue  \
# 0            Pizza Place         Grocery Store  Furniture / Home Store
# 1             Playground            Public Art                    Café
# 18      Football Stadium             BBQ Joint                    Park
# 24           Coffee Shop            Hobby Shop            Burger Joint
# 58     Electronics Store                  Café                Pharmacy
# 59                Museum                 Trail                    Café
# 67                   Zoo        Farmers Market     Fried Chicken Joint
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                     Zoo   Fried Chicken Joint     French Restaurant
# 1                Boutique            Comic Shop        Cosmetics Shop
# 18  Outdoors & Recreation     Outdoor Sculpture            Sports Bar
# 24               Wine Bar           IT Services              Dive Bar
# 58                    Zoo   Fried Chicken Joint     French Restaurant
# 59          Grocery Store                   Gym              Gym Pool
# 67      French Restaurant      Football Stadium            Food Truck
#
#       9th Most Common Venue 10th Most Common Venue
# 0          Football Stadium             Food Truck
# 1             Deli / Bodega            Music Store
# 18            Tour Provider         Baggage Locker
# 24     Fast Food Restaurant    Fried Chicken Joint
# 58         Football Stadium             Food Truck
# 59  Scandinavian Restaurant               Bus Stop
# 67        Food & Drink Shop                   Food

# %% [markdown]
# #### Cluster 3

# %%
minneapolis_merged.loc[minneapolis_merged['Cluster Labels'] == 2, minneapolis_merged.columns[[1] + list(range(5, minneapolis_merged.shape[1]))]]
# Out:
#          Neighborhoods    1st Most Common Venue     2nd Most Common Venue  \
# 2     Cedar-Isles-Dean             Intersection                    Bridge
# 3         East Calhoun           Ice Cream Shop            Scenic Lookout
# 4           East Isles              Pizza Place               Coffee Shop
# 5              Kenwood      American Restaurant                 Bookstore
# 6           Lowry Hill        Electronics Store             Acupuncturist
# 7      Lowry Hill East              Pizza Place               Coffee Shop
# 8         West Calhoun       Frozen Yogurt Shop               Event Space
# 10             Folwell             Dessert Shop               Art Gallery
# 13       Shingle Creek           Gymnastics Gym          Business Service
# 14             Victory             Fishing Spot                     Plaza
# 16       Downtown East              Coffee Shop       American Restaurant
# 17       Downtown West              Pizza Place       American Restaurant
# 19         Loring Park  New American Restaurant          Sculpture Garden
# 20          North Loop                  Brewery      Gym / Fitness Center
# 22              Cooper              Coffee Shop             Moving Target
# 23            Hiawatha              Pizza Place              Dance Studio
# 25          Longfellow                     Pool                Playground
# 26              Seward               Playground         Convenience Store
# 27            Harrison      American Restaurant                      Park
# 28           Hawthorne              Video Store                     Hotel
# 29              Jordan     Gym / Fitness Center                      Food
# 30          Near North                      ATM                 BBQ Joint
# 35               Field              Pizza Place            Clothing Store
# 36                Hale                      Zoo              Concert Hall
# 38           Minnehaha                   Garden                    Lounge
# 39         Morris Park                    Hotel                Playground
# 40            Northrup         Sculpture Garden                    Garden
# 43             Wenonah                     Road            Baseball Field
# 44        Audubon Park        Convenience Store            Cosmetics Shop
# 46           Bottineau                     Park          Theme Restaurant
# 47       Columbia Park                      Gym                Skate Park
# 48             Holland                BBQ Joint                Restaurant
# 49          Logan Park              Art Gallery                   Brewery
# 51      Northeast Park              Pizza Place            Sandwich Place
# 52            Sheridan                 Dive Bar                       Bar
# 55          Waite Park   Furniture / Home Store                       Bar
# 57  East Phillips,, ,                       Bar              Antique Shop
# 61            Bancroft              Yoga Studio             Grocery Store
# 62              Bryant            Deli / Bodega       American Restaurant
# 64            Corcoran              Music Store                Hobby Shop
# 65             Lyndale               Poke Place                 Gastropub
# 68            Whittier    Vietnamese Restaurant        Mexican Restaurant
# 70        East Harriet                   Garden                      Park
# 71              Fulton             Antique Shop    Thrift / Vintage Store
# 75           Lynnhurst              Art Gallery              Burger Joint
# 76          Tangletown                      Spa            Cosmetics Shop
# 77              Windom   Furniture / Home Store             Garden Center
# 78     Cedar-Riverside                  Theater                       Bar
# 79                Como      American Restaurant       Sporting Goods Shop
# 80        Marcy-Holmes          Coworking Space  Bike Rental / Bike Share
# 82       Prospect Park             Hockey Arena               Art Gallery
# 83          University              Bus Station            Sandwich Place
#
#             3rd Most Common Venue            4th Most Common Venue  \
# 2             American Restaurant             Gym / Fitness Center
# 3                           Beach                       Comic Shop
# 4                        Boutique               Mexican Restaurant
# 5                           Trail                   Baseball Field
# 6             American Restaurant                   Ice Cream Shop
# 7                        Boutique                   Breakfast Spot
# 8                    Burger Joint                    Moving Target
# 10                        Brewery                              Spa
# 13     Construction & Landscaping                              Zoo
# 14                     Playground                        Speakeasy
# 16                            Bar                            Hotel
# 17                  Grocery Store                             Park
# 19                    Coffee Shop               Salon / Barbershop
# 20                            Bar              American Restaurant
# 22                   Liquor Store                       Print Shop
# 23                 Clothing Store                       Playground
# 25           Fast Food Restaurant                              Zoo
# 26               Spiritual Center                    Bowling Alley
# 27  Vegetarian / Vegan Restaurant                    Grocery Store
# 28                       Vineyard       Construction & Landscaping
# 29                          Diner                      Coffee Shop
# 30                           Café  Southern / Soul Food Restaurant
# 35                      Pet Store                              Bar
# 36                 Breakfast Spot                            Beach
# 38                            Spa                      Music Venue
# 39                 Clothing Store             Gym / Fitness Center
# 40              Outdoor Sculpture          New American Restaurant
# 43                         Garden                              Zoo
# 44                       Pharmacy               Chinese Restaurant
# 46                            Bar                Food & Drink Shop
# 47                       Mountain                  Motorcycle Shop
# 48               Baseball Stadium                              Zoo
# 49         Furniture / Home Store                       Food Truck
# 51           Fast Food Restaurant                      Coffee Shop
# 52            American Restaurant                      Art Gallery
# 55                          Hotel                      Video Store
# 57                    Beer Garden                      Gas Station
# 61           Fast Food Restaurant             Caribbean Restaurant
# 62                     Food Truck                       Taco Place
# 64                    Yoga Studio             Outdoor Supply Store
# 65                    Bus Station           Thrift / Vintage Store
# 68                    Coffee Shop             Caribbean Restaurant
# 70           Other Great Outdoors                              Pub
# 71                      Pet Store                   Shipping Store
# 75                      Juice Bar                      Coffee Shop
# 76                 Soccer Stadium                       Hobby Shop
# 77                          Hotel                              Spa
# 78                 Sandwich Place              Sporting Goods Shop
# 79                          Hotel                            Motel
# 80        New American Restaurant                             Café
# 82           Gym / Fitness Center             Fast Food Restaurant
# 83                        Exhibit                              Zoo
#
#               5th Most Common Venue       6th Most Common Venue  \
# 2                             Beach  Tourist Information Center
# 3                    Cosmetics Shop              Massage Studio
# 4                               ATM                         Spa
# 5                              Café                 Tailor Shop
# 6                               Bar                   Gift Shop
# 7                       Yoga Studio         American Restaurant
# 8                       Bus Station       Performing Arts Venue
# 10                      Bus Station           Convenience Store
# 13               Frozen Yogurt Shop         Fried Chicken Joint
# 14                             Road                 Beer Garden
# 16             Gym / Fitness Center              Sandwich Place
# 17                              Bar           French Restaurant
# 19                          Theater         Indie Movie Theater
# 20                              Spa                        Café
# 22                       Playground                 Record Shop
# 23                   Massage Studio               Garden Center
# 25                   Farmers Market         Fried Chicken Joint
# 26                 Sushi Restaurant          Mexican Restaurant
# 27                Convenience Store           Fish & Chips Shop
# 28                             Food           Fish & Chips Shop
# 29              American Restaurant                 Gas Station
# 30                      Gas Station          Chinese Restaurant
# 35                    Moving Target               Movie Theater
# 36                Martial Arts Dojo      Thrift / Vintage Store
# 38                          Dog Run                  Donut Shop
# 39                              Zoo              Farmers Market
# 40                             Park                 Art Gallery
# 43             Fast Food Restaurant          Frozen Yogurt Shop
# 44                           Bakery                        Park
# 46             Gym / Fitness Center                 Beer Garden
# 47                             Farm                         Zoo
# 48             Fast Food Restaurant          Frozen Yogurt Shop
# 49                Convenience Store                       Diner
# 51                     Liquor Store             Supplement Shop
# 52                      Coffee Shop               Grocery Store
# 55             Fast Food Restaurant          Frozen Yogurt Shop
# 57                       Donut Shop                     Dog Run
# 61  Southern / Soul Food Restaurant              Discount Store
# 62                              Zoo        Fast Food Restaurant
# 64              American Restaurant                Antique Shop
# 65                             Park              Cosmetics Shop
# 68                    Grocery Store                      Bakery
# 70                     Intersection         American Restaurant
# 71                      Bus Station                 Coffee Shop
# 75                        Gift Shop    Bike Rental / Bike Share
# 76             Other Great Outdoors                         Zoo
# 77                       Taco Place        Fast Food Restaurant
# 78                      Bus Station          Chinese Restaurant
# 79                  Bed & Breakfast          Mexican Restaurant
# 80              American Restaurant               Design Studio
# 82                   Scenic Lookout               Grocery Store
# 83             Fast Food Restaurant         Fried Chicken Joint
#
#             7th Most Common Venue          8th Most Common Venue  \
# 2                             Zoo                           Food
# 3                      Food Truck              Food & Drink Shop
# 4                Sushi Restaurant                    Supermarket
# 5                          Bakery                           Park
# 6                      Restaurant                   Liquor Store
# 7                            Café             Mexican Restaurant
# 8                           Trail                    Flea Market
# 10                       Bus Stop                   Intersection
# 13              French Restaurant               Football Stadium
# 14                            Zoo                    Flower Shop
# 16                            Pub            Japanese Restaurant
# 17               Football Stadium                     Food Truck
# 19  Paper / Office Supplies Store             Seafood Restaurant
# 20                     Food Truck             Seafood Restaurant
# 22           Fast Food Restaurant                   Burger Joint
# 23                     Food Truck               Football Stadium
# 25              French Restaurant               Football Stadium
# 26                Organic Grocery                            Gym
# 27                   Fishing Spot                    Flea Market
# 28                   Fishing Spot                    Flea Market
# 29                  Deli / Bodega                   Dance Studio
# 30               Greek Restaurant                    Coffee Shop
# 35                    Coffee Shop        Comfort Food Restaurant
# 36         Furniture / Home Store                   Antique Shop
# 38             Frozen Yogurt Shop            Fried Chicken Joint
# 39              French Restaurant               Football Stadium
# 40                     Art Museum               Baseball Stadium
# 43            Fried Chicken Joint              French Restaurant
# 44                  Event Service               Department Store
# 46                    Coffee Shop              German Restaurant
# 47            Fried Chicken Joint              French Restaurant
# 48            Fried Chicken Joint              French Restaurant
# 49                    Yoga Studio                  Hot Dog Joint
# 51                  Big Box Store             Salon / Barbershop
# 52                 Massage Studio                   Optical Shop
# 55            Fried Chicken Joint              French Restaurant
# 57                         Garden         Furniture / Home Store
# 61                  Hot Dog Joint                 Farmers Market
# 62             Frozen Yogurt Shop            Fried Chicken Joint
# 64                        Theater                          Train
# 65             Chinese Restaurant                            Gym
# 68                    Pizza Place                 Cosmetics Shop
# 70        Health & Beauty Service  Paper / Office Supplies Store
# 71                   Gourmet Shop                         Casino
# 75                          Trail                      Pet Store
# 76                 Farmers Market               Football Stadium
# 77            Fried Chicken Joint              French Restaurant
# 78                    Coffee Shop         College Residence Hall
# 79                       Boutique             Miscellaneous Shop
# 80               Greek Restaurant                  Historic Site
# 82                           Park              Recreation Center
# 83              French Restaurant               Football Stadium
#
#       9th Most Common Venue 10th Most Common Venue
# 2               Flea Market            Flower Shop
# 3                      Food   Fast Food Restaurant
# 4               Gas Station                  Diner
# 5       Arts & Crafts Store            Flower Shop
# 6                Steakhouse                   Food
# 7          Asian Restaurant                  Diner
# 8               Flower Shop                   Food
# 10        Electronics Store            Flower Shop
# 13               Food Truck      Food & Drink Shop
# 14        Fish & Chips Shop            Flea Market
# 16                      ATM               Pharmacy
# 17        Food & Drink Shop         Farmers Market
# 19                     Road           Dance Studio
# 20              Men's Store         Breakfast Spot
# 22   Furniture / Home Store            Gas Station
# 23     Fast Food Restaurant      Food & Drink Shop
# 25               Food Truck      Food & Drink Shop
# 26           Sandwich Place                   Café
# 27              Flower Shop                    Zoo
# 28              Flower Shop                    Zoo
# 29              Flower Shop     Chinese Restaurant
# 30                      Gym   Fast Food Restaurant
# 35       Mexican Restaurant               Boutique
# 36               Playground             Donut Shop
# 38        French Restaurant       Football Stadium
# 39               Food Truck      Food & Drink Shop
# 40                     Food              Mini Golf
# 43         Football Stadium             Food Truck
# 44            Jewelry Store           Home Service
# 46                BBQ Joint         Scenic Lookout
# 47         Football Stadium             Food Truck
# 48         Football Stadium             Food Truck
# 49                      Gym     Mexican Restaurant
# 51               Smoke Shop              Gift Shop
# 52                Bookstore             Steakhouse
# 55         Football Stadium             Food Truck
# 57       Frozen Yogurt Shop    Fried Chicken Joint
# 61         Football Stadium             Food Truck
# 62        French Restaurant       Football Stadium
# 64        Fish & Chips Shop           Fishing Spot
# 65              Art Gallery       Arepa Restaurant
# 68             Dessert Shop     Chinese Restaurant
# 70           Farmers Market   Fast Food Restaurant
# 71              Art Gallery             Food Truck
# 75       English Restaurant             Playground
# 76               Food Truck      Food & Drink Shop
# 77         Football Stadium             Food Truck
# 78                Rock Club                    ATM
# 79  State / Provincial Park                Brewery
# 80              Flower Shop                   Food
# 82                     Food            Flower Shop
# 83               Food Truck      Food & Drink Shop

# %% [markdown]
# ## 1.4.5 Key plots

# %% [markdown]
# ## Office location for rents
# ![title](min_csv_data/neigborhood.JPG)
#
# ## Major reail
# ![title](min_csv_data/major_retail.png)
#
# ## Industrial employment
# ![title](min_csv_data/industrial_empl.jpg)
#
# ## Police Incidence
# ![title](min_csv_data/police_incidence.jpg)

# %% [markdown]
# ## Piecing the plots together
# ![title](min_csv_data/groupings_plot.jpg)

# %% [markdown]
# ### Interpretation or Key to the above plot(Click on any icon to display)
# > - 1. Green pentagons are office space on lease
# > - 2. Orange diamonds represnt Major Retail Centers
# > - 3. bright Yellow Diamonds represents transit stations
# > - 4. Brown diamonds at the lower sections of the map represents Industrial Employment centers
# > - 5. Red small circles are Crime(police incidents)
# > - 6. Big bubbles are the clusters

# %% [markdown]
# ## 1.4.6 RESULTS
# ### From the superposition of clusters of venues, transit stations, industrial emploment district, lease space for offices,
# ### major retail centers and crime dustribution, we are able to narrow our choices for a location to 5 key locations namely
# > - N 1st street - Cluster 2 N-loop location
# > - 4th Ave s -Cluster 2 Down town East
# > - 6th street Cluster 1 Eliot park
# > - 9th Street Cluster 1 Eliot Park
# > - Washington Ave N Cluster 3 Nicolet Island
# Analysis from the plots below will help further differentiate these locations to obtain the most suitable location for the establishment
# the business headquarters and warehouse location

# %% [markdown]
# ## 1.4.7 Population Distribution
# ![title](min_csv_data/pop_data.JPG)

# %% [markdown]
# #### Bar chart depicting population distribution for All race types in the communities of Minneapolis

# %% [markdown]
# ![title](min_csv_data/horizon2.JPG)
# ![title](min_csv_data/horizon3.JPG)

# %%
pop_plot = p_data.plot(kind='barh', figsize=(15, 15))
pop_plot.set_ylabel("Communities")
pop_plot.set_xlabel("Population size per Race")
pop_plot.set_title("Population Distribution by Race in Menneapolis Communities")
# Out:
# Text(0.5, 1.0, 'Population Distribution by Race in Menneapolis Communities')

# %% [markdown]
#  for an average of about 30,000 person in each community, white are the most predominant race followed by African American and the Asian population are most concentrated around the university community, Near North and Camdem area

# %% [markdown]
# #### Horizontal Bar chart showing population distribution of Asians in the various communities in Mnneapolis

# %% [markdown]
# ![title](min_csv_data/horizon_bar.JPG)

# %%
pd_asian = p_data['Asian '].plot(kind='barh', figsize=(10, 5))
pd_asian.set_ylabel("Communities")
pd_asian.set_xlabel("Population of Asians per community")
pd_asian.set_title("Asian Population Distribution in Menneapolis Communities")
pd_asian

# %% [markdown]
# horizontal bar chart depicting only the size of the Asian population per community per as its a key determining factor for my client business decisons.
# we clearly see Asian population desity most concentrated around the University, Near North and Camden communities respectively

# %% [markdown]
# ### PIE Chart to visualize percentage distribution of the population

# %% [markdown]
# ![title](min_csv_data/pie_chart.JPG)

# %%
# autopct create %, start angle represent starting point
p_data['Asian '].plot(kind='pie',
                            figsize=(7, 9),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (university)
                            shadow=True,       # add shadow      
                            )

plt.title("Asian Population Distribution in Menneapolis Communities")
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %% [markdown]
# #### From the above bar and pie charts we can infere that communities with the most concentration of Asian poputlation are
# > - University with a 21.7% of the total population, it belongs to cluster 3
# > -  Near North with a 21.6% of the total population, belonging to cluster 3
# > -  Candem with a 14.1% of the total population and in cluster 2 as well
# this is logical as a greater proportions of ASIAN restaurants are also concentrated there

# %% [markdown]
# ### 1.4.8 Discussions
# There were trade-offs between several locations that a compromised had to be reached as to the best venue, you have situations were venues were lacking in certain major criteria and rich in others. I had to consider factors most desired by my client in helping eliminate venues and narrowing my final target e.g Bus stops and transit stations had preeminence over closeness to tier one restaurants. office space was another major factor since my client corporate image and culture is that of opulence and dominance.
# I equally leverage a free source for Geolocator genetor OPENCAGE API. reidtration is free and access is gauranteed.
# Data sourcong took alot of time as some data had to be scrapped from the web like a comprehensive list of communities and their corresponding neighborhoods
#
# You will notice some graphical and table representation

# %% [markdown]
# ### 1.4.9 Conclusions

# %% [markdown]
# #### Considering the initial creteria stated in section 1 -problem statement,
# > - Office size within 2000 - 7000 sq ft
# > - Atleast one Asian restaurant with 2 mile radius, coffee shop and Grocery
# > - Asian community be most predominant or most important in the area
# > - within one mile from bus station or bus-stop
# > - Manufacturing plant be Within 5 miles of major Office and a major retail center
# > - Manufacturing plant with 5 miles of a industrial employment district
# > - Low crime rate

# %% [markdown]
# From the above analysis its deduced the the best fit for the business headquarters would be
# ### 400 N 1st St , sqft 6638 priced at $105876.1/yr
# This location practically meets all location creteria, its found in Cluster 2 North Loop, less than 2 miles away from the warehouse district and distribution center favorable for manufacturing and warehousing
# 0.5 miles away from major Asain (Chinesse and Vietnamese) Restaurants, less than 2 miles miles away from the University and Near North
# in clusters 3 which has the most densely population settlements of Asians and very low in crime, it equaly sit at the heart of the transit stations and closest to the major distribution centers and under5 miles from the industrial employement distric
# the office space of  6638 sqft i well suited as illustrated below.

# %% [markdown]
# ![title](best_office_loc.JPG)

# %% [markdown]
# ### Actual Street and Office Location view of 400 N 1st St, MN

# %% [markdown]
# ![title](https://images2.loopnet.com/i2/JOGlXfKZzDX__VYnYa5pMhE568iIOpajoqGh8Y76mS8/110/image.jpg)

# %% [markdown]
# # 2.0 Links to the entire week 2 and week one codes on my github
# > - week 2- Battle of Neighborhood Code link
#      https://github.com/eyonka/Coursera_Capstone/blob/master/battle_nghd_wk2.ipynb
#
# > - Weeek 1 - Battle of neighborhood code link
#     https://github.com/eyonka/Coursera_Capstone/blob/master/courseracapstone-wk-1.ipynb

# %% [markdown]
# THE END!

# %% [markdown]
# Its been a very Challenging experience, yet rewarding. lots new libraires, tools and methods learned.
# Many thanks to my classmates and Instructors alike.
# Please leave a message if you have dounbts in any section of this presentation and i will be glad to return your text
# Thank you!
# Elvis Yem
